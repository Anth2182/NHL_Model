# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

# Read from Google Sheets
sheet_id = '1cD0nCI-oNWyutWKUSY8vHdHPpccrEOyv28Bdkx_IlWU'
gid = '410298993'
sheet_url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid}'

print("Reading Google Sheet...")
df = pd.read_csv(sheet_url)
print(f"Loaded {len(df)} rows")
print(df.head())

# Create SQL Server connection using SQLAlchemy
connection_string = "DRIVER={ODBC Driver 17 for SQL Server};SERVER=ANTHPC\\SQLEXPRESS;DATABASE=NHL_01;Trusted_Connection=yes;"
connection_url = URL.create("mssql+pyodbc", query={"odbc_connect": connection_string})

print("\nConnecting to SQL Server...")
engine = create_engine(connection_url)

# Load to SQL Server
table_name = 'TeamAdvancedStats_202425'
print(f"\nLoading data to table '{table_name}'...")
df.to_sql(table_name, engine, if_exists='replace', index=False)

print("Done!")
# Out:
# Reading Google Sheet...
# Loaded 160 rows
#   team  season name team.1    position situation  games_played  \
# 0  VGK    2024  VGK    VGK  Team Level     other            82
# 1  VGK    2024  VGK    VGK  Team Level       all            82
# 2  VGK    2024  VGK    VGK  Team Level      5on5            82
# 3  VGK    2024  VGK    VGK  Team Level      4on5            82
# 4  VGK    2024  VGK    VGK  Team Level      5on4            82
#
#    xGoalsPercentage  corsiPercentage  fenwickPercentage  ...  \
# 0              0.55             0.45               0.46  ...
# 1              0.54             0.51               0.52  ...
# 2              0.53             0.51               0.52  ...
# 3              0.16             0.13               0.15  ...
# 4              0.92             0.88               0.88  ...
#
#    scoreAdjustedShotsAttemptsAgainst  unblockedShotAttemptsAgainst  \
# 0                              253.0                           178
# ...
